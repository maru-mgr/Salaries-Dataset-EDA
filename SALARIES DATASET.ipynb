# %%
import pandas as pd

# %%
sal_data = pd.read_csv('Salaries.csv')
sal_data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # 1. Display Top 10 Rows of the Dataset

# %%
sal_data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# # 2. Display Bottom 10 rows of the dataset

# %%
sal_data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %% [markdown]
# # 3. Display 10 random sample from the dataset

# %%
sal_data.sample(10)
# Out:
#             Id         EmployeeName  \
# 64680    64681           Anson Dong
# 108214  108215  Lakesha R Actkinson
# 15040    15041    JONATHAN LOIACANO
# 130202  130203             Ava Byrd
# 3072      3073  DAVID COLCLOUGH III
# 46559    46560     Victoria Gavidia
# 20704    20705            JOHN CHAN
# 3895      3896     CRISTOBAL IBORRA
# 136893  136894           Yuet L Lam
# 130776  130777    Giovanni J Aquino
#
#                                            JobTitle    BasePay  OvertimePay  \
# 64680                 District Attry's Investigator   37076.00         0.00
# 108214                       Patient Care Assistant    4176.09         0.00
# 15040                      PRINCIPAL CIVIL ENGINEER   77848.51         0.00
# 130202                  Health Care Billing Clerk 2   68985.03         0.00
# 3072                              POLICE OFFICER II  103358.02     29850.53
# 46559                       Claims Investigator, CA   96005.00         0.00
# ...

# %% [markdown]
# # 4. Check datatype of the column of the dataset

# %%
sal_data.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %% [markdown]
# # 5. Find the shape of the dataset

# %%
sal_data.shape
# Out:
# (148654, 13)

# %% [markdown]
# # 6. Get overall information about the dataset

# %%
sal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# # 7. Check null values within the dataset and remove them if found.

# %%
sal_data.isnull().any()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay              True
# OvertimePay          True
# OtherPay             True
# Benefits             True
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Notes                True
# Agency              False
# Status               True
# dtype: bool

# %%
sal_data.isnull().sum() # finding the total number of null values in each column
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
sal_data.isnull().sum().sum() #finding the total number of null values within the overall dataset.
# Out:
# 334088

# %%
sal_data.isnull().sum(axis = 1) #rowwise check
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    2
# 148650    6
# 148651    6
# 148652    6
# 148653    2
# Length: 148654, dtype: int64

# %%
(sal_data.isnull().sum()/len(sal_data))*100 #nullvalues in percentage
# Out:
# Id                    0.000000
# EmployeeName          0.000000
# JobTitle              0.000000
# BasePay               0.409676
# OvertimePay           0.002691
# OtherPay              0.002691
# Benefits             24.326961
# TotalPay              0.000000
# TotalPayBenefits      0.000000
# Year                  0.000000
# Notes               100.000000
# Agency                0.000000
# Status              100.000000
# dtype: float64

# %%
#removing/dropping a column
#sal_data = sal_data.drop(['Notes','Status','Agency','Id'], axis = 1)
sal_data.drop(['Notes','Status','Agency','Id'], axis = 1, inplace = True)

# %%
sal_data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 8. Check duplicate value and remove duplicate values

# %%
sal_data[sal_data.duplicated()]
# Out:
#         EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 148650  Not provided  Not provided      NaN          NaN       NaN       NaN
# 148651  Not provided  Not provided      NaN          NaN       NaN       NaN
# 148652  Not provided  Not provided      NaN          NaN       NaN       NaN
#
#         TotalPay  TotalPayBenefits  Year
# 148650       0.0               0.0  2014
# 148651       0.0               0.0  2014
# 148652       0.0               0.0  2014

# %%
sal_data.duplicated().any() #check duplicates
# Out:
# True

# %%
sal_data.drop_duplicates(inplace = True)
#sal_data = sal_data.drop_duplicates()

# %%
sal_data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148646       Not provided                                    Not provided
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 9. Get overall statistics about the dataframe

# %%
sal_data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448840    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148651.000000     148651.000000  148651.000000
# mean    74769.830909      93694.445667    2012.522613
# std     50516.398338      62792.756431       1.117529
# min      -618.130000       -618.130000    2011.000000
# 25%     36169.340000      44071.405000    2012.000000
# ...

# %% [markdown]
# # 10. Find occurrence of the employee Names(top 5)

# %%
sal_data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
sal_data['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# KEVIN LEE        9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# # 11. Find the number of unique job titles

# %%
sal_data['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# # 12. Total number of job titiles containing 'Captain'

# %%
sal_data[sal_data['JobTitle'].str.contains('Captain', case = False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  \
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88
# ...                    ...                                    ...        ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21
# 120867     Michael J Moran                              Captain 3    7660.00
# 122361  Michael V Rolovich              Captain, Fire Suppression       0.00
# 126588    Stephen M Tittel                              Captain 3   68491.89
# 132232     Jeanne M Seyler              Captain, Fire Suppression   61039.43
#
# ...

# %%
len(sal_data[sal_data['JobTitle'].str.contains('Captain', case = False)])
# Out:
# 552

# %%
sum(sal_data['JobTitle'].str.contains('Captain', case = False))
# Out:
# 552

# %% [markdown]
# # 13. Display all the employee names from the fire department

# %%
sal_data[sal_data['JobTitle'].str.contains('Fire', case = False)]
# Out:
#               EmployeeName                                          JobTitle  \
# 4          PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 6                ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8           MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9       JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10           ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                    ...                                               ...
# 145956    Kenneth C Farris                                       Firefighter
# 147556       Edward A Dunn                                       Firefighter
# 148021      Kari A Johnson                                       Firefighter
# 148209        Sheryl K Lee                                       Firefighter
# 148554     Lawrence F Gatt                             Fire Alarm Dispatcher
#
# ...

# %%
sal_data[sal_data['JobTitle'].str.contains('Fire', case = False)][['EmployeeName','JobTitle']]
# Out:
#               EmployeeName                                          JobTitle
# 4          PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 6                ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8           MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9       JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10           ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                    ...                                               ...
# 145956    Kenneth C Farris                                       Firefighter
# 147556       Edward A Dunn                                       Firefighter
# 148021      Kari A Johnson                                       Firefighter
# 148209        Sheryl K Lee                                       Firefighter
# 148554     Lawrence F Gatt                             Fire Alarm Dispatcher
#
# [5879 rows x 2 columns]

# %% [markdown]
# # 14.  find miminum, maximum, average basepay

# %%
sal_data['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148646          NaN
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653         0.00
# Name: BasePay, Length: 148651, dtype: float64

# %%
sal_data['BasePay'].min()
# Out:
# -166.01

# %%
sal_data['BasePay'].max()
# Out:
# 319275.01

# %%
sal_data['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# # 15. Replace 'Not Provided' in Employee Name column to NaN

# %%
import numpy as np
sal_data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
sal_data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148646         Not provided
# 148647       Joann Anderson
# 148648          Leon Walker
# 148649        Roy I Tillery
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148651, dtype: object

# %%
sal_data['EmployeeName'] = sal_data['EmployeeName'].replace('Not provided', np.nan)

# %%
sal_data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148646                NaN                                    Not provided
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
sal_data['JobTitle'] = sal_data['JobTitle'].replace('Not provided', np.nan)

# %%
sal_data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148646                NaN                                             NaN
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 16. Drop the rows having 5 missing value

# %%
sal_data.isnull().sum(axis = 1)>=5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148646     True
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Length: 148651, dtype: bool

# %%
sal_data.drop(sal_data[sal_data.isnull().sum(axis = 1)>=5].index,axis = 0, inplace = True) 
# removing records containing null values more than or equal to 5

# %%
sal_data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 17. Find the job title of Albert Pardini

# %%
sal_data[sal_data['EmployeeName'].str.contains('Albert Pardini', case = False)]
# Out:
#          EmployeeName                         JobTitle    BasePay  \
# 2      ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 36519  Albert Pardini                        Captain 3  196265.04
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 2        106088.18  16452.60       NaN  335279.91         335279.91  2011
# 36519         0.00  11404.04  46326.21  207669.08         253995.29  2012

# %%
sal_data[sal_data['EmployeeName'].str.contains('Albert Pardini', case = False)][['EmployeeName','JobTitle']]
# Out:
#          EmployeeName                         JobTitle
# 2      ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)
# 36519  Albert Pardini                        Captain 3

# %% [markdown]
# # 18. How much does Albert Pardini make (including benefits)?

# %%
sal_data[sal_data['EmployeeName'].str.contains('Albert Pardini', case = False)][['EmployeeName','TotalPayBenefits']]
# Out:
#          EmployeeName  TotalPayBenefits
# 2      ALBERT PARDINI         335279.91
# 36519  Albert Pardini         253995.29

# %% [markdown]
# # 19. Display name of the person having the highest basepay.

# %%
sal_data['BasePay'].max()
# Out:
# 319275.01

# %%
sal_data[sal_data['BasePay'].max() == sal_data['BasePay']]
# Out:
#          EmployeeName         JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01          0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year
# 72925  86533.21  339282.07         425815.28  2013

# %%
sal_data[sal_data['BasePay'].max() == sal_data['BasePay']][['EmployeeName', 'BasePay' ]]
# Out:
#          EmployeeName    BasePay
# 72925  Gregory P Suhr  319275.01

# %% [markdown]
# # 20. Find the average basepay of all employee per year.

# %%
sal_data.groupby('Year')['BasePay'].mean() #option 1
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal_data.groupby('Year').mean()
# Out:
# C:\Users\itsma\AppData\Local\Temp\ipykernel_7100\2784617144.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sal_data.groupby('Year').mean()
#            BasePay  OvertimePay     OtherPay      Benefits      TotalPay  \
# Year
# 2011  63595.956517  4531.065429  3617.081926           NaN  71744.103871
# 2012  65436.406857  5023.417824  3653.437583  26439.966967  74113.262265
# 2013  69630.030216  5281.641980  3819.969007  23829.076572  77611.443142
# 2014  66564.421924  5401.993737  3505.421251  24789.601756  75471.836912
#
#       TotalPayBenefits
# Year
# 2011      71744.103871
# 2012     100553.229232
# 2013     101440.519714
# 2014     100261.438668

# %%
sal_data.groupby('Year').mean()['BasePay'] #option 2
# Out:
# C:\Users\itsma\AppData\Local\Temp\ipykernel_7100\3365740481.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sal_data.groupby('Year').mean()['BasePay'] #option 2
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# # 21. Find Average Basepay of all empolyee per jobtitile

# %%
sal_data.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2158, dtype: float64

# %%
sal_data.groupby('JobTitle')['BasePay'].mean().sort_values(ascending = False)
#sorting through highest average value.
# Out:
# JobTitle
# Chief of Police                            309767.683333
# Chief, Fire Department                     304232.340000
# Gen Mgr, Public Trnsp Dept                 297769.413333
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)     285262.000000
# Dep Dir for Investments, Ret               276153.765000
#                                                ...
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN         0.000000
# Captain, (Fire Department)                           NaN
# Drug Court Coordinator                               NaN
# IS Technician Assistant                              NaN
# Public Safety Comm Tech                              NaN
# Name: BasePay, Length: 2158, dtype: float64

# %% [markdown]
# # 22. Find Average Basepay of all empolyees having job titile accountant

# %%
sal_data[sal_data['JobTitle'].str.contains('Accountant', case = False)]['BasePay'].mean()
# Out:
# 72245.57241071429

# %% [markdown]
# # 23. Find top 5 most common jobs

# %%
sal_data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# # 24. Find the employees having the most repetative lastname.

# %%
sal_data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
sal_data['EmployeeName'][14126].split()[1]
# Out:
# 'LIGE'

# %%
lastname = []

for name in sal_data['EmployeeName']:
    lastname.append(name.split()[0])
lastname
# Out:
# ['NATHANIEL',
#  'GARY',
#  'ALBERT',
#  'CHRISTOPHER',
#  'PATRICK',
#  'DAVID',
#  'ALSON',
#  'DAVID',
#  'MICHAEL',
#  'JOANNE',
#  'ARTHUR',
#  'PATRICIA',
#  'EDWARD',
#  'JOHN',
#  'DAVID',
#  'RICHARD',
#  'AMY',
#  'SEBASTIAN',
#  'MARTY',
#  'ELLEN',
#  'VENUS',
#  'JUDY',
#  'GEORGE',
#  'VICTOR',
#  'JOSEPH',
#  'GREGORY',
#  'JOHN',
#  'RAYMOND',
#  'DENISE',
#  'MONICA',
#  'HARLAN',
#  'DAVID',
#  'GARY',
#  'JOHN',
#  'JOSE',
#  'KHOA',
#  'SUSAN',
#  'JAMES',
#  'JONES',
#  'BRENDAN',
#  'MICHAEL',
#  'THOMAS',
#  'THOMAS',
#  'MICHAEL',
#  'SHARON',
#  'EDWIN',
#  'BRYAN',
#  'TRENT',
#  'JAMES',
#  'KEN',
#  'KIRK',
#  'BARBARA',
#  'MICHAEL',
#  'DARRYL',
#  'RAY',
#  'KEVIN',
#  'BENJAMIN',
#  'MARK',
#  'DOUGLAS',
#  'AI-KYUNG',
#  'KENNETH',
#  'ANNA',
#  'JAMES',
#  'CHARLES',
#  'GREGORY',
#  'RICHARD',
#  'ROBERT',
#  'EDWARD',
#  'THOMAS',
#  'WING',
#  'GEORGE',
#  'RICHARD',
#  'LAWRENCE',
#  'MONIQUE',
#  'ANTONIO',
#  'MARK',
#  'KEVIN',
#  'BERT',
# ...

# %%
sal_data[['EmployeeName']]
# Out:
#              EmployeeName
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148645   Carolyn A Wilson
# 148647     Joann Anderson
# 148648        Leon Walker
# 148649      Roy I Tillery
# 148653          Joe Lopez
#
# [148650 rows x 1 columns]

# %%
sal_data['EmployeeName'][148645].split()
# Out:
# ['Carolyn', 'A', 'Wilson']
